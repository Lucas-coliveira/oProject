# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
cv2.__version__
# Out:
# '4.7.0'

# %%
img = cv2.imread("imteste.jpg",cv2.IMREAD_COLOR)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Padrão open cv é BGR isso altera as cores da imagem

# %%
plt.imshow(img)

# %% [markdown]
# ##### Porem é possivel converter para RGB

# %%
irgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(irgb)
